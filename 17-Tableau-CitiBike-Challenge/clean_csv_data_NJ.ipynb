# %%
# dependencies
import random
import pandas as pd
import requests
import json
import numpy as np
import glob
import json
import csv
import warnings

warnings.simplefilter("error")

# %%
#18
file1_pd_18 = pd.read_csv("JC-201801-citibike-tripdata.csv")
file2_pd_18 = pd.read_csv("JC-201802-citibike-tripdata.csv")
file3_pd_18 = pd.read_csv("JC-201803-citibike-tripdata.csv")
file4_pd_18 = pd.read_csv("JC-201804-citibike-tripdata.csv")
file5_pd_18 = pd.read_csv("JC-201805-citibike-tripdata.csv")
file6_pd_18 = pd.read_csv("JC-201806-citibike-tripdata.csv")
file7_pd_18 = pd.read_csv("JC-201807-citibike-tripdata.csv")
file8_pd_18 = pd.read_csv("JC-201808-citibike-tripdata.csv")
file9_pd_18 = pd.read_csv("JC-201809-citibike-tripdata.csv")
file10_pd_18 = pd.read_csv("JC-201810-citibike-tripdata.csv")
file11_pd_18 = pd.read_csv("JC-201811-citibike-tripdata.csv")
file12_pd_18 = pd.read_csv("JC-201812-citibike-tripdata.csv")
#19
file1_pd_19 = pd.read_csv("JC-201901-citibike-tripdata.csv")
file2_pd_19 = pd.read_csv("JC-201902-citibike-tripdata.csv")
file3_pd_19 = pd.read_csv("JC-201903-citibike-tripdata.csv")
file4_pd_19 = pd.read_csv("JC-201904-citibike-tripdata.csv")
file5_pd_19 = pd.read_csv("JC-201905-citibike-tripdata.csv")
file6_pd_19 = pd.read_csv("JC-201906-citibike-tripdata.csv")
file7_pd_19 = pd.read_csv("JC-201907-citibike-tripdata.csv")
file8_pd_19 = pd.read_csv("JC-201908-citibike-tripdata.csv")
file9_pd_19 = pd.read_csv("JC-201909-citibike-tripdata.csv")
file10_pd_19 = pd.read_csv("JC-201910-citibike-tripdata.csv")
file11_pd_19 = pd.read_csv("JC-201911-citibike-tripdata.csv")
file12_pd_19 = pd.read_csv("JC-201912-citibike-tripdata.csv")
#20
file1_pd_20 = pd.read_csv("JC-202001-citibike-tripdata.csv")
file2_pd_20 = pd.read_csv("JC-202002-citibike-tripdata.csv")
file3_pd_20 = pd.read_csv("JC-202003-citibike-tripdata.csv")
file4_pd_20 = pd.read_csv("JC-202004-citibike-tripdata.csv")
file5_pd_20 = pd.read_csv("JC-202005-citibike-tripdata.csv")
file6_pd_20 = pd.read_csv("JC-202006-citibike-tripdata.csv")
file7_pd_20 = pd.read_csv("JC-202007-citibike-tripdata.csv")
file8_pd_20 = pd.read_csv("JC-202008-citibike-tripdata.csv")
file9_pd_20 = pd.read_csv("JC-202009-citibike-tripdata.csv")
file10_pd_20 = pd.read_csv("JC-202010-citibike-tripdata.csv")
file11_pd_20 = pd.read_csv("JC-202011-citibike-tripdata.csv")
file12_pd_20 = pd.read_csv("JC-202012-citibike-tripdata.csv")

# %%
citibike_tripdata_2018 = pd.concat([file1_pd_18, file2_pd_18, file3_pd_18,file4_pd_18,file5_pd_18, file6_pd_18, file7_pd_18,file8_pd_18,file9_pd_18, file10_pd_18, file11_pd_18,file12_pd_18],axis=0)

# %%
citibike_tripdata_2018.isnull().any()
# Out:
# tripduration               False
# starttime                  False
# stoptime                   False
# start station id           False
# start station name         False
# start station latitude     False
# start station longitude    False
# end station id             False
# end station name           False
# end station latitude       False
# end station longitude      False
# bikeid                     False
# usertype                   False
# birth year                 False
# gender                     False
# dtype: bool

# %%
citibike_tripdata_2018.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1           550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2           510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3           354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4           250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3199     Newport Pkwy
# ...

# %%
citibike_tripdata_2018_clean = citibike_tripdata_2018.dropna(axis=0).reset_index(drop=True)
citibike_tripdata_2018_clean.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1           550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2           510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3           354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4           250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3199     Newport Pkwy
# ...

# %%
citibike_tripdata_2018_clean["birth year"] = citibike_tripdata_2018_clean["birth year"].astype(int)

# %%
citibike_tripdata_2018_clean.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id             int64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id               int64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
citibike_tripdata_2018_clean.to_csv("CitibikeTripdata2018.csv", index=False)

# %%
citibike_tripdata_2019 = pd.concat([file1_pd_19, file2_pd_19, file3_pd_19,file4_pd_19,file5_pd_19, file6_pd_19, file7_pd_19,file8_pd_19,file9_pd_19, file10_pd_19, file11_pd_19,file12_pd_19],axis=0)

# %%
citibike_tripdata_2019.isnull().any()
# Out:
# tripduration               False
# starttime                  False
# stoptime                   False
# start station id           False
# start station name         False
# start station latitude     False
# start station longitude    False
# end station id             False
# end station name           False
# end station latitude       False
# end station longitude      False
# bikeid                     False
# usertype                   False
# birth year                 False
# gender                     False
# dtype: bool

# %%
citibike_tripdata_2019.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1           505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2           756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3          1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4          1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3214    Essex Light Rail
# ...

# %%
citibike_tripdata_2019_clean = citibike_tripdata_2019.dropna(axis=0).reset_index(drop=True)
citibike_tripdata_2019_clean.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1           505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2           756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3          1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4          1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3214    Essex Light Rail
# ...

# %%
citibike_tripdata_2019_clean["birth year"] = citibike_tripdata_2019_clean["birth year"].astype(int)
citibike_tripdata_2019_clean.dtypes
citibike_tripdata_2019_clean.to_csv("CitibikeTripdata2019.csv", index=False)

# %%
citibike_tripdata_2020 = pd.concat([file1_pd_20, file2_pd_20, file3_pd_20,file4_pd_20,file5_pd_20, file6_pd_20, file7_pd_20,file8_pd_20,file9_pd_20, file10_pd_20, file11_pd_20, file12_pd_20],axis=0)

# %%
citibike_tripdata_2020.isnull().any()
citibike_tripdata_2020_clean = citibike_tripdata_2020.dropna(axis=0).reset_index(drop=True)

# %%
citibike_tripdata_2020_clean["birth year"] = citibike_tripdata_2020_clean["birth year"].astype(int)
citibike_tripdata_2020_clean.dtypes
citibike_tripdata_2020_clean.to_csv("CitibikeTripdata2020.csv", index=False)

# %%
# combine all citi bikeshare csv into one mega csv

# path = "data"
# all_files = glob.glob(path + "/*.csv")
# frame = pd.DataFrame()
# timeYr = []
# df=pd.read_csv(file_,index_col=None, header=0)

# for file_ in all_files:
#     df = pd.read_csv(file_,index_col=None, header=0)
#     timeYr.append(df)
# frame = pd.concat(timeYr)
# frame.to_csv("clean_csv_data.csv", index=False)

# %%
# # Script to merge several CSVs into one

# import glob
# import csv

# # Change delimiter to the appropriate one in CSV
delimiter = ';'

csvs = glob.glob('*.csv')

f = open('merged_data.csv', 'wb')
master_csv = csv.writer(f)

# # Take the header of the first CSV and make it the master header
first_csv = open(csvs[0], 'rb')
headers = first_csv.readline().strip().split(delimiter)
master_csv.writerow(headers)
# # Write remaining rows
for line in first_csv:
    master_csv.writerow(line.strip().split(delimiter))

# # Read remaining CSVs and skip the first row
for file in csvs[1:]:
    current_csv = open(file, 'rb')
    for line_num, line in enumerate(current_csv):
         if line_num > 0:
            master_csv.writerow(line.strip().split(delimiter))
            
f.close()
# Out:
# Exception ignored in: <_io.FileIO name='merged_data.csv' mode='wb' closefd=True>
# Traceback (most recent call last):
#   File "<ipython-input-41-768d65e6a1dc>", line 12, in <module>
# ...
# Exception ignored in: <_io.FileIO name='JC-202010-citibike-tripdata.csv' mode='rb' closefd=True>
# Traceback (most recent call last):
#   File "<ipython-input-41-768d65e6a1dc>", line 15, in <module>
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-768d65e6a1dc> in <module>
#      14 # # Take the header of the first CSV and make it the master header
#      15 first_csv = open(csvs[0], 'rb')
# ---> 16 headers = first_csv.readline().strip().split(delimiter)
#      17 master_csv.writerow(headers)
#      18 # # Write remaining rows
#
# TypeError: a bytes-like object is required, not 'str'

# %%
# df.columns

# %%
# df.head()

# %%
# df['Year'] = df["stoptime"].str[:4]
# df['Month'] = df['stoptime'].str[5:7]
# df['Date'] = df["stoptime"].str[:10]
# df['Time_Hr'] = df["stoptime"].str[11:13]
# df.head()

# %%
# df.columns
