# %% [markdown]
# SVM and Logistic Regression Model Comparison

# %% [markdown]
# Logistic Regression Model

# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in /opt/anaconda3/lib/python3.8/site-packages (0.0)
# Requirement already satisfied, skipping upgrade: scikit-learn in /opt/anaconda3/lib/python3.8/site-packages (from sklearn) (0.23.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.19.5)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (0.16.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.5.0)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (2.1.0)

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.8/site-packages (0.16.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head(100)
# Out:
#    koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0        CONFIRMED              0              0              0
# 1   FALSE POSITIVE              0              1              0
# 2   FALSE POSITIVE              0              1              0
# 3        CONFIRMED              0              0              0
# 4        CONFIRMED              0              0              0
# ..             ...            ...            ...            ...
# 95       CONFIRMED              0              0              0
# 96       CONFIRMED              0              0              0
# 97       CONFIRMED              0              0              0
# 98       CONFIRMED              0              0              0
# 99       CONFIRMED              0              0              0
#
#     koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0               0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1               0   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2               0    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3               0    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4               0    4.134435     1.050000e-05    -1.050000e-05   172.979370
# ..            ...         ...              ...              ...          ...
# 95              0    8.103633     2.030000e-05    -2.030000e-05   176.948600
# 96              0    4.715108     1.940000e-05    -1.940000e-05   134.961780
# 97              0    6.365840     8.060000e-06    -8.060000e-06   171.135750
# 98              0    3.040330     3.370000e-07    -3.370000e-07   169.949011
# 99              0   31.330461     3.980000e-05    -3.980000e-05   153.430310
#
#     koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0           0.003520  ...             -81      4.467           0.064
# 1           0.000581  ...            -176      4.544           0.044
# 2           0.000115  ...            -174      4.564           0.053
# 3           0.001130  ...            -211      4.438           0.070
# 4           0.001900  ...            -232      4.486           0.054
# ..               ...  ...             ...        ...             ...
# 95          0.002050  ...            -146      4.574           0.054
# 96          0.003240  ...            -146      4.574           0.054
# 97          0.001000  ...            -155      4.554           0.042
# 98          0.000089  ...            -151      4.519           0.084
# 99          0.001030  ...            -105      4.581           0.010
#
#     koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0           -0.096     0.927          0.105         -0.061  291.93423
# 1           -0.176     0.868          0.233         -0.078  297.00482
# 2           -0.168     0.791          0.201         -0.067  285.53461
# 3           -0.210     1.046          0.334         -0.133  288.75488
# 4           -0.229     0.972          0.315         -0.105  296.28613
# ..             ...       ...            ...            ...        ...
# 95          -0.041     0.732          0.062         -0.068  283.22141
# 96          -0.041     0.732          0.062         -0.068  283.22141
# 97          -0.168     0.849          0.212         -0.071  291.14951
# 98          -0.063     0.791          0.071         -0.087  299.31610
# 99          -0.085     0.817          0.080         -0.029  292.23676
#
#           dec  koi_kepmag
# 0   48.141651      15.347
# 1   48.134129      15.436
# 2   48.285210      15.597
# 3   48.226200      15.509
# 4   48.224670      15.714
# ..        ...         ...
# 95  40.421829      15.289
# 96  40.421829      15.289
# 97  40.420521      15.090
# 98  40.822380      15.028
# 99  41.085880      15.855
#
# [100 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
selected_features = df[['koi_fpflag_nt','koi_fpflag_ss','koi_fpflag_co','koi_fpflag_ec',
                        'koi_period','koi_period_err1','koi_period_err2',
                        'koi_time0bk','koi_time0bk_err1','koi_time0bk_err2',
                        'koi_impact','koi_impact_err1','koi_impact_err2',
                        'koi_duration','koi_duration_err1','koi_duration_err2',
                        'koi_depth','koi_depth_err1','koi_depth_err2',
                        'koi_prad','koi_prad_err1','koi_prad_err2',
                        'koi_teq','koi_insol','koi_insol_err1','koi_insol_err2',
                        'koi_model_snr','koi_steff','koi_steff_err1','koi_steff_err2',
                        'koi_slogg','koi_slogg_err1','koi_slogg_err2',
                        'koi_srad','koi_srad_err1','koi_srad_err2',
                        'ra','dec','koi_kepmag']]
selected_features.head(20)
# Out:
#     koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0               0              0              0              0   54.418383
# 1               0              1              0              0   19.899140
# 2               0              1              0              0    1.736952
# 3               0              0              0              0    2.525592
# 4               0              0              0              0    4.134435
# 5               0              0              0              0    2.566589
# 6               0              0              0              0   16.068647
# 7               0              0              0              0    2.470613
# 8               0              1              0              0    2.204735
# 9               0              0              0              0    3.522498
# 10              0              0              0              0    3.709214
# 11              0              1              0              0   11.521446
# 12              0              1              0              0   19.221389
# 13              0              1              0              0   16.469838
# 14              0              0              0              0    9.273582
# 15              0              0              0              0    6.029303
# 16              0              1              1              1    2.696371
# 17              0              0              0              0    3.941052
# 18              0              1              0              0  386.603053
# 19              0              0              0              0   21.676992
#
#     koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0      2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1      1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2      2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3      3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4      1.050000e-05    -1.050000e-05   172.979370          0.001900
# 5      1.780000e-05    -1.780000e-05   179.554370          0.004610
# 6      1.090000e-05    -1.090000e-05   173.621937          0.000517
# 7      2.700000e-08    -2.700000e-08   122.763305          0.000009
# 8      4.300000e-08    -4.300000e-08   121.358542          0.000016
# 9      1.980000e-07    -1.980000e-07   121.119423          0.000047
# 10     6.540000e-06    -6.540000e-06   133.983180          0.001430
# 11     1.980000e-06    -1.980000e-06   170.839688          0.000131
# 12     1.120000e-06    -1.120000e-06   184.552164          0.000045
# 13     1.360000e-05    -1.360000e-05   180.881761          0.000623
# 14     1.040000e-05    -1.040000e-05   173.258155          0.000877
# 15     5.510000e-06    -5.510000e-06   171.602959          0.000713
# 16     7.530000e-06    -7.530000e-06   170.737690          0.002340
# 17     1.090000e-05    -1.090000e-05   136.086620          0.002330
# 18     1.369000e-04    -1.369000e-04   166.342079          0.000299
# 19     7.010000e-05    -7.010000e-05   171.535940          0.002580
#
#     koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          -0.003520  ...             -81      4.467           0.064
# 1          -0.000581  ...            -176      4.544           0.044
# 2          -0.000115  ...            -174      4.564           0.053
# 3          -0.001130  ...            -211      4.438           0.070
# 4          -0.001900  ...            -232      4.486           0.054
# 5          -0.004610  ...            -232      4.486           0.054
# 6          -0.000517  ...             -83      4.485           0.083
# 7          -0.000009  ...             -78      4.457           0.024
# 8          -0.000016  ...             -89      4.019           0.033
# 9          -0.000047  ...            -137      4.169           0.055
# 10         -0.001430  ...            -117      4.407           0.085
# 11         -0.000131  ...            -172      4.554           0.033
# 12         -0.000045  ...            -200      4.496           0.052
# 13         -0.000623  ...            -153      4.517           0.088
# 14         -0.000877  ...            -146      4.583           0.065
# 15         -0.000713  ...            -123      4.648           0.020
# 16         -0.002340  ...            -149      4.504           0.090
# 17         -0.002330  ...             -77      4.440           0.098
# 18         -0.000299  ...             -79      4.081           0.014
# 19         -0.002580  ...             -79      4.500           0.075
#
#     koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0           -0.096     0.927          0.105         -0.061  291.93423
# 1           -0.176     0.868          0.233         -0.078  297.00482
# 2           -0.168     0.791          0.201         -0.067  285.53461
# 3           -0.210     1.046          0.334         -0.133  288.75488
# 4           -0.229     0.972          0.315         -0.105  296.28613
# 5           -0.229     0.972          0.315         -0.105  296.28613
# 6           -0.028     0.848          0.033         -0.072  286.99948
# 7           -0.024     0.964          0.038         -0.038  286.80847
# 8           -0.027     1.952          0.099         -0.110  292.24728
# 9           -0.045     1.451          0.110         -0.110  281.28812
# 10          -0.114     1.022          0.143         -0.107  295.64871
# 11          -0.176     0.848          0.224         -0.075  297.07993
# 12          -0.208     0.947          0.308         -0.096  295.81454
# 13          -0.072     0.786          0.088         -0.088  297.15442
# 14          -0.035     0.696          0.056         -0.068  288.13824
# 15          -0.056     0.672          0.062         -0.036  283.71088
# 16          -0.060     0.819          0.067         -0.082  283.76547
# 17          -0.045     0.910          0.057         -0.086  292.37613
# 18          -0.014     1.580          0.064         -0.064  292.27374
# 19          -0.020     0.828          0.032         -0.065  290.46512
#
#           dec  koi_kepmag
# 0   48.141651      15.347
# 1   48.134129      15.436
# 2   48.285210      15.597
# 3   48.226200      15.509
# 4   48.224670      15.714
# 5   48.224670      15.714
# 6   48.375790      15.841
# 7   49.316399      11.338
# 8   47.969521      10.463
# 9   42.451080      13.563
# 10  48.495560      12.772
# 11  47.597401      15.472
# 12  47.690350      15.341
# 13  47.668701      15.788
# 14  47.724449      15.302
# 15  47.863270      15.784
# 16  47.804298      15.269
# 17  47.880989      15.416
# 18  37.671558      12.394
# 19  47.929180      15.377
#
# [20 rows x 39 columns]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
# get X and y variables
y = df["koi_disposition"]
X = selected_features

# %%
# split the data to train and test values

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
# Import dependencies
from sklearn.preprocessing import LabelEncoder, MinMaxScaler,StandardScaler
#from tensorflow.keras.utils import to_categorical

# scale the data with StandardScaler
X_scaler = StandardScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)


print(encoded_y_test)
# Out:
# [0 2 2 ... 2 2 1]

# %% [markdown]
# # Train the Model

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model
# Out:
# LogisticRegression()

# %%
# fit the data and make predictions
model.fit(X_train_scaled, encoded_y_train)
predictions = model.predict(X_test_scaled)
predictions
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# array([0, 2, 2, ..., 2, 2, 1])

# %%
print(f"Training Data Score: {model.score(X_train_scaled, encoded_y_train)}")
print(f"Testing Data Score: {model.score(X_test_scaled, encoded_y_test)}")
# Out:
# Training Data Score: 0.887659736791913
# Testing Data Score: 0.8895881006864989

# %%
# Calculate classification report
from sklearn.metrics import classification_report
print(classification_report(encoded_y_test, predictions,
                           target_names =["confirmed", "false positive", "candidate"]))
# Out:
#                 precision    recall  f1-score   support
#
#      confirmed       0.85      0.69      0.76       422
# false positive       0.75      0.87      0.80       450
#      candidate       0.99      1.00      0.99       876
#
#       accuracy                           0.89      1748
#      macro avg       0.86      0.85      0.85      1748
#   weighted avg       0.89      0.89      0.89      1748

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [10, 50, 100],
             'max_iter':[200, 500, 1000]}
grid = GridSearchCV(model,param_grid, verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train_scaled, encoded_y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] C=10, max_iter=200 ..............................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.4s remaining:    0.0s
# [CV] .................. C=10, max_iter=200, score=0.886, total=   0.2s
# [CV] C=10, max_iter=200 ..............................................
# [CV] .................. C=10, max_iter=200, score=0.884, total=   0.2s
# [CV] C=10, max_iter=200 ..............................................
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] .................. C=10, max_iter=200, score=0.883, total=   0.2s
# [CV] C=10, max_iter=200 ..............................................
# [CV] .................. C=10, max_iter=200, score=0.898, total=   0.2s
# [CV] C=10, max_iter=200 ..............................................
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] .................. C=10, max_iter=200, score=0.871, total=   0.2s
# [CV] C=10, max_iter=500 ..............................................
# [CV] .................. C=10, max_iter=500, score=0.886, total=   0.3s
# [CV] C=10, max_iter=500 ..............................................
# [CV] .................. C=10, max_iter=500, score=0.884, total=   0.4s
# [CV] C=10, max_iter=500 ..............................................
# [CV] .................. C=10, max_iter=500, score=0.883, total=   0.3s
# [CV] C=10, max_iter=500 ..............................................
# [CV] .................. C=10, max_iter=500, score=0.899, total=   0.3s
# [CV] C=10, max_iter=500 ..............................................
# [CV] .................. C=10, max_iter=500, score=0.871, total=   0.4s
# [CV] C=10, max_iter=1000 .............................................
# [CV] ................. C=10, max_iter=1000, score=0.886, total=   0.4s
# [CV] C=10, max_iter=1000 .............................................
# [CV] ................. C=10, max_iter=1000, score=0.884, total=   0.4s
# [CV] C=10, max_iter=1000 .............................................
# [CV] ................. C=10, max_iter=1000, score=0.883, total=   0.3s
# [CV] C=10, max_iter=1000 .............................................
# [CV] ................. C=10, max_iter=1000, score=0.899, total=   0.4s
# [CV] C=10, max_iter=1000 .............................................
# [CV] ................. C=10, max_iter=1000, score=0.871, total=   0.4s
# [CV] C=50, max_iter=200 ..............................................
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] .................. C=50, max_iter=200, score=0.886, total=   0.2s
# [CV] C=50, max_iter=200 ..............................................
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] .................. C=50, max_iter=200, score=0.883, total=   0.2s
# [CV] C=50, max_iter=200 ..............................................
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] .................. C=50, max_iter=200, score=0.883, total=   0.2s
# [CV] C=50, max_iter=200 ..............................................
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] .................. C=50, max_iter=200, score=0.896, total=   0.2s
# [CV] C=50, max_iter=200 ..............................................
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] .................. C=50, max_iter=200, score=0.872, total=   0.2s
# [CV] C=50, max_iter=500 ..............................................
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] .................. C=50, max_iter=500, score=0.885, total=   0.6s
# [CV] C=50, max_iter=500 ..............................................
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] .................. C=50, max_iter=500, score=0.883, total=   0.6s
# [CV] C=50, max_iter=500 ..............................................
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] .................. C=50, max_iter=500, score=0.883, total=   0.6s
# [CV] C=50, max_iter=500 ..............................................
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] .................. C=50, max_iter=500, score=0.896, total=   0.6s
# [CV] C=50, max_iter=500 ..............................................
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] .................. C=50, max_iter=500, score=0.874, total=   0.6s
# [CV] C=50, max_iter=1000 .............................................
# [CV] ................. C=50, max_iter=1000, score=0.885, total=   0.8s
# [CV] C=50, max_iter=1000 .............................................
# [CV] ................. C=50, max_iter=1000, score=0.883, total=   0.8s
# [CV] C=50, max_iter=1000 .............................................
# [CV] ................. C=50, max_iter=1000, score=0.883, total=   0.8s
# [CV] C=50, max_iter=1000 .............................................
# [CV] ................. C=50, max_iter=1000, score=0.896, total=   0.8s
# [CV] C=50, max_iter=1000 .............................................
# [CV] ................. C=50, max_iter=1000, score=0.874, total=   0.8s
# [CV] C=100, max_iter=200 .............................................
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] ................. C=100, max_iter=200, score=0.886, total=   0.3s
# [CV] C=100, max_iter=200 .............................................
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] ................. C=100, max_iter=200, score=0.883, total=   0.3s
# [CV] C=100, max_iter=200 .............................................
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] ................. C=100, max_iter=200, score=0.882, total=   0.3s
# [CV] C=100, max_iter=200 .............................................
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] ................. C=100, max_iter=200, score=0.896, total=   0.3s
# [CV] C=100, max_iter=200 .............................................
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] ................. C=100, max_iter=200, score=0.873, total=   0.3s
# [CV] C=100, max_iter=500 .............................................
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] ................. C=100, max_iter=500, score=0.884, total=   0.7s
# [CV] C=100, max_iter=500 .............................................
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] ................. C=100, max_iter=500, score=0.883, total=   0.7s
# [CV] C=100, max_iter=500 .............................................
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] ................. C=100, max_iter=500, score=0.883, total=   0.7s
# [CV] C=100, max_iter=500 .............................................
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] ................. C=100, max_iter=500, score=0.897, total=   0.7s
# [CV] C=100, max_iter=500 .............................................
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] ................. C=100, max_iter=500, score=0.875, total=   0.7s
# [CV] C=100, max_iter=1000 ............................................
# [CV] ................ C=100, max_iter=1000, score=0.885, total=   1.0s
# [CV] C=100, max_iter=1000 ............................................
# [CV] ................ C=100, max_iter=1000, score=0.883, total=   1.1s
# [CV] C=100, max_iter=1000 ............................................
# [CV] ................ C=100, max_iter=1000, score=0.881, total=   1.0s
# [CV] C=100, max_iter=1000 ............................................
# [CV] ................ C=100, max_iter=1000, score=0.896, total=   1.2s
# [CV] C=100, max_iter=1000 ............................................
# [CV] ................ C=100, max_iter=1000, score=0.875, total=   1.2s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:   23.0s finished
# GridSearchCV(estimator=LogisticRegression(),
#              param_grid={'C': [10, 50, 100], 'max_iter': [200, 500, 1000]},
#              verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'C': 10, 'max_iter': 500}
# 0.88441754779179

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
# import joblib
# filename = 'your_name.sav'
# joblib.dump(your_model, filename)

import joblib
filename = 'logistig_reg_model.sav'
joblib.dump(model, filename)
# Out:
# ['logistig_reg_model.sav']
